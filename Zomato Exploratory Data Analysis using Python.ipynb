# %% [markdown]
# # Zomato Exploratory Data Analysis Using Python

# %% [markdown]
# ## Project Overview:
# This project focuses on a comprehensive analysis of restaurant data from Zomato, encompassing diverse countries and regions.
# The objective was to gain insights into global restaurant trends, regional variations in cuisine preferences,
# and factors influencing restaurant ratings across different countries.

# %% [markdown]
# # Objectives:
#
# 1.Analyze Zomato's international restaurant dataset to understand global dining preferences.
# 2.Identify regional influences on restaurant ratings and cuisine choices.
# 3.Provide actionable insights for restaurant owners and global food enthusia

# %% [markdown]
# # Data Collection:
# The international Zomato dataset was collected from Kaggle,
# encompassing restaurant details, user ratings, geographical data, and more.
#
# ## Data preprocessing involved
# Data cleaning, Handling of missing values, and the encoding of categorical variables.

# %% [markdown]
# ## Importing important libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\SoumyaDas\Desktop\Zomato.csv",encoding='latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ## Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# ## Describing the statistcal values from the data

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ## Checking the null values in the data

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ## Exploring the numerical variables

# %%
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Cuisines']

# %% [markdown]
# ## Reading country code file for better analysis

# %%
df_country=pd.read_excel(r"C:\Users\SoumyaDas\Desktop\Country-Code.xlsx")

# %%
df_country.head(10)
# Out:
#    Country Code       Country
# 0             1         India
# 1            14     Australia
# 2            30        Brazil
# 3            37        Canada
# 4            94     Indonesia
# 5           148   New Zealand
# 6           162   Phillipines
# 7           166         Qatar
# 8           184     Singapore
# 9           189  South Africa

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# ## Merging the data frames

# %%
final_df=pd.merge(df,df_country,on='Country Code',how='left')
final_df.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
final_df.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %% [markdown]
# ## Number of records for the individual country

# %%
country_names=final_df.Country.value_counts().index

# %%
country_val=final_df.Country.value_counts().value

# %% [markdown]
# ## Top three country that uses Zomato

# %%
plt.pie(country_val[:3],labels=country_names[:3],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x16aea159c60>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %% [markdown]
# ## From the above chart it is concluded that the maximum number of transactions has been made by India as compare to others UK and USA

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
ratings=final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})

# %% [markdown]
# ratings

# %% [markdown]
# ##### Observation 1:Whenever the rating is from 4.5 to 4.9,it indicates that it is excellent
# Observation 2:Whenever the rating is from 4.0 to 4.5,it indicates that it is very good.
# Observation 3:Whenever the rating is from 3.5 to 3.9,it indicates that it is good.
# Observation 4:Whenever the rating is from 3.0 to 3.4,it indicates that it is average.
# Observation 5:Whenever the rating is from 2.5 to 2.9,it indicates that it is poor.

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)
sns.barplot(x="Aggregate rating",y="Rating Count",hue='Rating color',data=ratings,palette=['white','red','orange','yellow','green','green'])
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %% [markdown]
# ### Observation:
#     1.Not rated count is very high
#     2.Maximum number of rating are between 2.5 to 3.4

# %%
sns.countplot(x='Rating color',data=ratings,palette=['blue','red','orange','yellow','green','green'])
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %% [markdown]
# ## Find the countries name that gave zero ratings

# %%
country_rating=final_df[['Country','Aggregate rating']]

# %%
country_rating
# Out:
#           Country  Aggregate rating
# 0     Phillipines               4.8
# 1     Phillipines               4.5
# 2     Phillipines               4.4
# 3     Phillipines               4.9
# 4     Phillipines               4.8
# ...           ...               ...
# 9546       Turkey               4.1
# 9547       Turkey               4.2
# 9548       Turkey               3.7
# 9549       Turkey               4.0
# 9550       Turkey               4.0
#
# [9551 rows x 2 columns]

# %%
final_df[final_df['Rating color']=='White'].groupby('Country').size().reset_index()
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %% [markdown]
# ## Observations:
# Maximum zero rating are from indian customers

# %% [markdown]
# ## Which currency used by which country

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
country_cr=final_df.groupby(['Country','Currency']).size().reset_index()
country_cr
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(£)    80
# 14   United States               Dollar($)   434

# %% [markdown]
# ## Which countries have online deliveries option

# %%
final_df[final_df['Has Online delivery']=='Yes'].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %%
Delivery=final_df[['Has Online delivery','Country']].groupby(['Has Online delivery','Country']).size().reset_index()
Delivery
# Out:
#    Has Online delivery         Country     0
# 0                   No       Australia    24
# 1                   No          Brazil    60
# 2                   No          Canada     4
# 3                   No           India  6229
# 4                   No       Indonesia    21
# 5                   No     New Zealand    40
# 6                   No     Phillipines    22
# 7                   No           Qatar    20
# 8                   No       Singapore    20
# 9                   No    South Africa    60
# 10                  No       Sri Lanka    20
# 11                  No          Turkey    34
# 12                  No             UAE    32
# 13                  No  United Kingdom    80
# 14                  No   United States   434
# 15                 Yes           India  2423
# 16                 Yes             UAE    28

# %% [markdown]
# ### Observations:
# 1.Online deliveries are available in India and UAE

# %%
cities_values=final_df.City.value_counts().values
cities_labels=final_df.City.value_counts().index

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# ### Top three cities that uses Zomato

# %%
plt.pie(cities_values[:3],labels=cities_labels[:3],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x16aec770520>,
# ...
#  [Text(-0.6836225695617262, 0.8617773392157762, 'New Delhi'),
#   Text(0.24897482286810813, -1.0714530029720364, 'Gurgaon'),
#   Text(0.9941442744692855, -0.47082604169686504, 'Noida')],
#  [Text(-0.37288503794275973, 0.47006036684496877, '71.35%'),
#   Text(0.13580444883714987, -0.5844289107120197, '14.57%'),
#   Text(0.542260513346883, -0.25681420456192633, '14.08%')])

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
Best_cuisines=final_df[['Cuisines','Country','Aggregate rating']].groupby(['Cuisines','Aggregate rating']).size().reset_index()
Best_cuisines
# Out:
#                                        Cuisines  Aggregate rating  0
# 0                                       Afghani               0.0  3
# 1                                       Afghani               2.9  1
# 2                     Afghani, Mughlai, Chinese               0.0  1
# 3                         Afghani, North Indian               0.0  1
# 4     Afghani, North Indian, Pakistani, Arabian               0.0  1
# ...                                         ...               ... ..
# 3919                       Western, Asian, Cafe               4.2  1
# 3920                 Western, Fusion, Fast Food               3.2  1
# 3921                              World Cuisine               4.9  1
# 3922            World Cuisine, Mexican, Italian               4.4  1
# 3923            World Cuisine, Patisserie, Cafe               4.2  1
#
# [3924 rows x 3 columns]

# %%
final_df[final_df['Aggregate rating']>4].groupby('Cuisines').size().reset_index()
# Out:
#                                Cuisines   0
# 0                               African   1
# 1                   African, Portuguese   1
# 2                              American  15
# 3               American, Asian, Burger   1
# 4    American, Asian, European, Seafood   1
# ..                                  ...  ..
# 657          Vietnamese, Fish and Chips   1
# 658                Western, Asian, Cafe   1
# 659                       World Cuisine   1
# 660     World Cuisine, Mexican, Italian   1
# 661     World Cuisine, Patisserie, Cafe   1
#
# [662 rows x 2 columns]

# %%
India_data=final_df[final_df['Country']=='India']

# %%
cuisine_ratings = India_data.groupby('Cuisines')['Aggregate rating'].mean().reset_index()
cuisine_ratings
# Out:
#                                        Cuisines  Aggregate rating
# 0                                       Afghani          0.725000
# 1                     Afghani, Mughlai, Chinese          0.000000
# 2                         Afghani, North Indian          0.000000
# 3     Afghani, North Indian, Pakistani, Arabian          0.000000
# 4                                      American          2.066667
# ...                                         ...               ...
# 1387                       Tibetan, Street Food          0.000000
# 1388                                    Turkish          2.950000
# 1389       Turkish, Arabian, Moroccan, Lebanese          0.000000
# 1390     Turkish, Mediterranean, Middle Eastern          4.300000
# 1391                                 Vietnamese          4.000000
#
# [1392 rows x 2 columns]

# %%
top_cuisines = cuisine_ratings.sort_values(by='Aggregate rating', ascending=False)

# %%
print(top_cuisines.head(10))
# Out:
#                                               Cuisines  Aggregate rating
# 725                       Italian, Bakery, Continental               4.9
# 927                                  Mughlai, Lucknowi               4.9
# 864                    Mexican, American, Healthy Food               4.9
# 575              European, Mediterranean, North Indian               4.8
# 724                           Italian, American, Pizza               4.8
# 495                 Continental, Middle Eastern, Asian               4.8
# 948             North Indian, American, Asian, Biryani               4.7
# 867                 Mexican, American, Tex-Mex, Burger               4.7
# 465                Continental, Italian, Asian, Indian               4.7
# 414  Continental, American, Italian, North Indian, ...               4.7

# %% [markdown]
# ## Conclusion:
#     Most liked cuisines with highest ratings in India.
